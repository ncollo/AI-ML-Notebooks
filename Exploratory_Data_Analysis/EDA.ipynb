# %% [markdown]
# # Expected Outcomes:
# ### By the end of this lab, you should be able to:
#
# <ol><li>Load and explore a dataset using basic descriptive statistics.
# <li>Use visualizations (histograms, box plots, scatter plots) to identify patterns in the data.
# <li>Perform a correlation analysis to understand relationships between features.
# <li>Interpret the results of EDA to inform the next steps in the machine learning workflow.</ol>
# This exercise will help solidify your understanding of the importance of EDA in machine learning and provide you with practical skills for data analysis and visualization.

# %% [markdown]
# ## Step 1: Load and Explore the Dataset
# Load the Iris dataset using scikit-learn and convert it into a pandas DataFrame.

# %%
from sklearn.datasets import load_iris
import pandas as pd

# Load the Iris dataset
iris = load_iris()
data = pd.DataFrame(iris.data, columns=iris.feature_names)

# Add the target variable (species)
data['species'] = iris.target

# Display the first few rows of the dataset
print(data.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
#print(data.describe())

print(data.info())
#print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# None

# %%
data['species'].value_counts()
# Out:
# species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %% [markdown]
# # Step 2: Visualize the Data
# 1) Create histograms of each numerical feature (sepal length, sepal width, petal length, petal width) to visualize the distribution of each feature.

# %%
import matplotlib.pyplot as plt
# Plot histograms for each feature
data.hist(figsize=(8, 8))
plt.suptitle("Feature Distributions")
plt.show()

# %% [markdown]
# 2) Box plots to visualize the range and detect outliers for each feature, grouped by the species of the iris flower.

# %%
import seaborn as sns

# Plot box plots for each feature grouped by species
sns.boxplot(x='species', y='sepal length (cm)', data=data)
plt.title('Sepal Length Distribution by Species')
plt.show()

sns.boxplot(x='species', y='sepal width (cm)', data=data)
plt.title('Sepal Width Distribution by Species')
plt.show()

sns.boxplot(x='species', y='petal length (cm)', data=data)
plt.title('Petal Length Distribution by Species')
plt.show()

sns.boxplot(x='species', y='petal width (cm)', data=data)
plt.title('Petal Width Distribution by Species')
plt.show()

# %% [markdown]
# 3) Scatter plots to visualize the relationships between different pairs of features. Use different colors to represent different species.

# %%
# Pairwise scatter plots colored by species
sns.pairplot(data, hue='species', palette='Set1')
plt.show()

# %% [markdown]
# ## Step 3: Correlation Analysis
# 1) Compute the correlation matrix for the numerical features to understand how each feature relates to others.
#
# Typically, a correlation matrix is “square”, with the same variables shown in the rows and columns. The matrix depicts the correlation between all the possible pairs of values in a table. It is a powerful tool to summarize a large dataset and to identify and visualize patterns in the given data.<br>
# In a correlation matrix, each variable is represented by a row and a column, and the cells show the correlation between them. The number in each cell represents the strength and direction of the correlation, with positive numbers indicating positive correlations (when one variable increases, the other variable tends to increase) and negative numbers indicating negative correlations (when one variable increases, the other variable tends to decrease).<br>
# The line of 1.00s going from the top left to the bottom right is the main diagonal, which shows that each variable always perfectly correlates with itself. This matrix is symmetrical, with the same correlation is shown above the main diagonal being a mirror image of those below the main diagonal

# %%
# Compute correlation matrix
corr_matrix = data.iloc[:, :-1].corr()
print("Correlation Matrix:")
print(corr_matrix)
# Out:
# Correlation Matrix:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %% [markdown]
# 2) Visualize the correlation matrix using a heatmap to better understand the relationships between the features.
#
# ### How to Read a Correlation Matrix?
# In this section, we will learn how to read a correlation matrix, a vital skill for understanding the relationships and strengths of association between multiple variables:
#
# <ul><li>Look at the number in each cell to see the strength and direction of the correlation.
# <li>Positive numbers indicate positive correlations, while negative numbers indicate negative correlations.
# <li>The closer the number is to 1 (or -1), the stronger the correlation.
# <li>A number of 0 means there is no correlation between the two variables.</ul>

# %%
# Heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Iris Features')
plt.show()

# %% [markdown]
# 3) Interpret the correlation results: Identify the strongest and weakest correlations between the features and discuss how these insights might inform feature selection for machine learning models.

# %% [markdown]
# ## Step 4: Conclusions and Reflections
# <ol><li>Summarize key findings from the EDA, including:</li>
# <ul><li>The distribution of features across species.
# <li>Patterns observed in the visualizations.
# <li>Strong and weak correlations between the features.</ul>
# <li>Discussion:</li>
# <ul><li>How do different features distinguish between species?
# <li>Which features are most important based on correlation analysis?</il>
